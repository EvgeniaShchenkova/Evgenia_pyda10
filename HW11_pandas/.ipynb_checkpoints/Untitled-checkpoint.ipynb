# %%
import pandas as pd

# %% [markdown]
# Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
data_data = pd.read_csv('ratings.csv')


a = data_data[ data_data.rating == 5 ].groupby(['movieId']).rating.value_counts().head()
a.sort_values(ascending=False).head()

#Ответ movieId 1
# Out:
# movieId  rating
# 1        5.0       47
# 6        5.0       24
# 2        5.0        7
# 3        5.0        6
# 5        5.0        3
# Name: rating, dtype: int64

# %% [markdown]
# Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
data = pd.read_csv('power.csv')
filtered_yc = data[ (data['year']=='2005') | (data['year']=='2006') | (data['year']=='2007') | (data['year']=='2008') | (data['year']=='2009') | (data['year']=='2010') & (data['country']=='Latvia') | (data['country']=='Lithuania') | (data['country']=='Estonia')]
filtered_yc['category'].isin([4, 12, 21])

filtered_yc[filtered_year.quantity > 0 ]['quantity'].sum()
# Out:
# 96435561.69461147

# %%
Задание 3
Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
Примеры страниц (необязательно брать именно эти):
https://fortrader.org/quotes
https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
pd.read_html('https://www.banki.ru/products/currency/cb/', encoding='utf-8')[0]
# Out:
#                                                   Код  \
# 0                                                 USD
# 1                                                 EUR
# 2   @import "//cdn.banki.ru/static/bundles/ui-2013...
# 3                                                 AUD
# 4                                                 AZN
# 5                                                 AMD
# 6                                                 BYN
# 7                                                 BGN
# 8                                                 BRL
# 9                                                 HUF
# 10                                                KRW
# 11                                                HKD
# 12                                                DKK
# 13                                                INR
# 14                                                KZT
# 15                                                CAD
# ...
